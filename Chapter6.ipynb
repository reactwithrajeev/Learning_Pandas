# %% [markdown]
# # Reading and Writing Data (CSV, Excel, JSON, SQL)

# %% [raw]
# -- In real-world data analysis, you’ll usually work with external files — like CSVs, Excel sheets, JSON files, and even SQL databases.
#
# -- Pandas makes it super easy to read and write these formats. Let’s go through them one by one.

# %%
import pandas as pd

# %% [markdown]
# # ✅ 1. Reading Data

# %%
df = pd.read_csv("C:\Data Analytics\Python\Pandas\insurance.csv")
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# # 📂 Reading an Excel file

# %% [raw]
# -- ⚠️ Note: You need to install openpyxl
# -- pip install openpyxl

# %%
df2 = pd.read_excel("C:\Data Analytics\EXCEL ADVANCE\PROJECTS\Project -1 Hiring Process\Statistics.xlsx")
df2.head()
# Out:
#    application_id  Interview Taken on    Status event_name  \
# 0          383422 2014-05-01 11:40:49     Hired       Male
# 1          907518 2014-05-06 08:08:32     Hired     Female
# 2          176719 2014-05-06 08:08:54  Rejected       Male
# 3          429799 2014-05-02 16:28:59  Rejected     Female
# 4          253651 2014-05-02 16:32:26     Hired       Male
#
#               Department Post Name  Offered Salary
# 0     Service Department        c8         56553.0
# 1     Service Department        c5         22075.0
# 2     Service Department        c5         70069.0
# 3  Operations Department        i4          3207.0
# 4  Operations Department        i4         29668.0

# %% [markdown]
# # Reading a Json File

# %%
df3 = pd.read_json("C:\Users\Rajeev\Downloads\example_1.json")
df3.head()
# Out:
#   Cell In[4], line 1
#     df3 = pd.read_json("C:\Users\Rajeev\Downloads\example_1.json")
#                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df3 =  pd.read_json(r"C:\Users\Rajeev\Downloads\example_2.json")
df3.head()
# Out:
#                                                     quiz
# sport  {'q1': {'question': 'Which one is correct team...
# maths  {'q1': {'question': '5 + 7 = ?', 'options': ['...
